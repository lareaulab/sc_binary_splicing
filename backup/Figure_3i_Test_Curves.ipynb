# %%
# %run -i 'load_data.py'
import importlib
# importlib.reload(scp)
# importlib.reload(spu)
# sns.reset_orig()
from scipy.stats import chisquare
from scipy.stats import combine_pvalues
# %run -i 'test_functions.py'

# %%
pvals, selected_mrna, selected_mrna_only, selected_read = test_anova_filters(chen_PSI, chen_mrna_counts, mrna_per_event_chen, 
                chen_read_counts, chen_coverage_tab, chen_pca_clust, clusters = 'AC',  psi_min = 0.05, obs_min = 0.5, 
                      mrna_min = 10, read_min =10, dset_name = 'chen dataset;', correct_multitest = False)
# Out:
# intermediate exons: 1157
# ...
# not pass: 94
# tested exons: 1063

# %%
# figsize(6,4)
summary_plots(pvals, selected_mrna, selected_mrna_only, selected_read, dset_name='Chen', 
              p_lim=0.1, p_low = 0.00001, p_steps = 0.05, linear_p=False, beta=1)

# %%
pvals, selected_mrna, selected_mrna_only, selected_read = test_anova_filters(song_PSI, song_mrna_counts, mrna_per_event_song, 
                song_read_counts, song_coverage_tab, song_pca_clust, clusters = 'AC',  psi_min = 0.05, obs_min = 0.5, 
                      mrna_min = 10, read_min =10, dset_name = 'song dataset;', correct_multitest = False)
# Out:
# intermediate exons: 896
# ...
# not pass: 517
# tested exons: 379

# %%
# figsize(6,4)
summary_plots(pvals, selected_mrna, selected_mrna_only, selected_read, dset_name='Song', 
              p_lim=0.1, p_low = 0.00001, p_steps = 0.05, linear_p=False, beta=1)

# %%
pvals, selected_mrna, selected_mrna_only, selected_read = test_anova_filters(lescroart_PSI, lescroart_mrna_counts, mrna_per_event_lescroart, 
                lescroart_read_counts, lescroart_coverage_tab, lescroart_pca_clust, clusters = 'AC',  psi_min = 0.05, obs_min = 0.5, 
                      mrna_min = 10, read_min =10, dset_name = 'lescroart dataset;', correct_multitest = False)
# Out:
# intermediate exons: 921
# ...
# not pass: 716
# tested exons: 205

# %%
# figsize(6,4)
summary_plots(pvals, selected_mrna, selected_mrna_only, selected_read, dset_name='Lescroart', 
              p_lim=0.1, p_low = 0.00001, p_steps = 0.05, linear_p=False, beta=1)

# %%
pvals, selected_mrna, selected_mrna_only, selected_read = test_anova_filters(trapnell_PSI, trapnell_mrna_counts, mrna_per_event_trapnell, 
                trapnell_read_counts, trapnell_coverage_tab, trapnell_pca_clust, clusters = 'AC',  psi_min = 0.05, obs_min = 0.5, 
                      mrna_min = 10, read_min =10, dset_name = 'trapnell dataset;', correct_multitest = False)
# Out:
# intermediate exons: 809
# ...
# not pass: 96
# tested exons: 713

# %%
# figsize(6,4)
summary_plots(pvals, selected_mrna, selected_mrna_only, selected_read, dset_name='Lescroart', 
              p_lim=0.1, p_low = 0.00001, p_steps = 0.05, linear_p=False, beta=1)

# %%
# pvals, selected_mrna, selected_mrna_only, selected_read = test_spearman_filters(chen_PSI, chen_mrna_counts, mrna_per_event_chen, 
#                                                          chen_read_counts, chen_coverage_tab, 
#                       chen_pca_clust, clusters = 'AC',
#                      psi_min = 0.05, obs_min = 0.5, mrna_min = 10, read_min = 10, filter_obs = False, 
#                     dset_name = '', one_test = False, correct_multitest=False)

# %%
# pvals, selected_mrna, selected_mrna_only, selected_read = test_hypergeom_filters(chen_PSI, chen_mrna_counts, 
#                                                                                  mrna_per_event_chen, 
#                                                          chen_read_counts, chen_coverage_tab, chen_pca_clust.AC,
#                      psi_min = 0.05, psi_bin = 0.25, obs_min = 0.5, mrna_min = 10, read_min = 10, filter_obs = False, 
#                     dset_name = '')

# %%
# pvals, selected_mrna, selected_mrna_only, selected_read = test_chi_filters(chen_PSI, chen_mrna_counts, mrna_per_event_chen, 
#                                                          chen_read_counts, chen_coverage_tab, chen_pca_clust.AC, 
#                      psi_min = 0.2, psi_bin = 0.1, obs_min = 0.25, mrna_min = 5, read_min =10, filter_obs = False, 
#                     dset_name = '', correct_multitest = True)

# %%
# %run -i 'test_filter_finctions.py'

# %%
test_spearman_filters(chen_PSI, chen_mrna_counts, mrna_per_event_chen, 
                                                         chen_read_counts, chen_coverage_tab, 
                      chen_pca_clust, clusters = 'AC',
                     psi_min = 0.05, obs_min = 0.5, mrna_min = 10, read_min = 10, filter_obs = False, 
                    dset_name = '', one_test = False, correct_multitest=False)
# Out:
# ...
# not pass
# 2
# ...
# not pass
# 8
# ...
# not pass
# 3
# ...
# not pass
# 33
# ...
# not pass
# 1
# Selected intermediate exons: 114
# 0.6403508771929824
# 0.6929824561403509
# 0.631578947368421
# 0.7192982456140351
# 0.6929824561403509

# %%
test_anova_filters(chen_PSI, chen_mrna_counts, mrna_per_event_chen, 
                chen_read_counts, chen_coverage_tab, chen_pca_clust, clusters = 'AC',  psi_min = 0.05, obs_min = 0.5, 
                      mrna_min = 10, read_min =10, dset_name = 'chen dataset;', correct_multitest = False)
# Out:
# ...
# not pass: 40
# tested exons: 182
# ...
# not pass: 57
# tested exons: 355
# ...
# not pass: 15
# tested exons: 107
# ...
# not pass: 96
# tested exons: 1080
# ...
# not pass: 7
# tested exons: 215
# Selected intermediate exons: 215
# 0.6208791208791209
# 0.719626168224299
# 0.5154929577464789
# 0.47962962962962963
# 0.641860465116279

# %%
test_anova_filters(song_PSI, song_mrna_counts, mrna_per_event_song, 
                song_read_counts, song_coverage_tab, song_pca_clust, clusters = 'AC',  psi_min = 0.05, obs_min = 0.5, 
                      mrna_min = 10, read_min =10, dset_name = 'song dataset;', correct_multitest = False)
# Out:
# ...
# not pass: 52
# tested exons: 54
# ...
# not pass: 94
# tested exons: 84
# ...
# not pass: 360
# tested exons: 246
# ...
# not pass: 0
# tested exons: 54
# ...
# not pass: 0
# tested exons: 54
# Selected intermediate exons: 54
# 0.7407407407407407
# 0.7777777777777778
# 0.7222222222222222
# 0.7777777777777778
# 0.7592592592592593

# %%
test_chi_filters(chen_PSI, chen_mrna_counts, mrna_per_event_chen, 
                                                         chen_read_counts, chen_coverage_tab, chen_pca_clust.AC, 
                     psi_min = 0.1, psi_bin = 0.1, obs_min = 0.75, mrna_min = 10, read_min =10, filter_obs = False, 
                    dset_name = '', correct_multitest = True)
# Out:
# ...
# not pass: 10
# tested exons: 51
# ...
# not pass: 9
# tested exons: 112
# ...
# not pass: 3
# tested exons: 23
# ...
# not pass: 0
# tested exons: 297
# ...
# not pass: 0
# tested exons: 21
# Selected intermediate exons: 21
# 0.3333333333333333
# 0.2857142857142857
# 0.3333333333333333
# 0.3333333333333333
# 0.3333333333333333

# %%
[x in ['SRR2727048', 'SRR2727049'] for x in chen_PSI.columns]
# Out:
# [False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
np.nan+3
# Out:
# nan
